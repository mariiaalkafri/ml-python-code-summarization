# %% [markdown]
# # Train Code Summarization Model on Colab
#
# This notebook allows you to train the Seq2Seq model using Colab's GPU.
#
# ## 1. Upload Data
# 1. Zip your local folder: `src/`, `scripts/`, `data/`.
# 2. Upload the zip file to the Files section on the left.
# 3. Run the cell below to unzip.

# %%
# !unzip -q project_files.zip -d .
# !ls -R

# %% [markdown]
# ## 2. Install Dependencies

# %%
# !pip install tokenizers torch

# %% [markdown]
# ## 3. Verify GPU

# %%
import torch
if torch.cuda.is_available():
    print(f"GPU Available: {torch.cuda.get_device_name(0)}")
else:
    print("WARNING: Running on CPU. Go to Runtime > Change runtime type > Hardware accelerator > GPU")

# %% [markdown]
# ## 4. Run Training

# %%
# !python scripts/train.py

# %% [markdown]
# ## 5. Download Model
# After training, download the `models/best.pt` file to perform inference locally.

# %%
from google.colab import files
files.download('models/best.pt')
